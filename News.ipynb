# %% [markdown]
# <a href="https://colab.research.google.com/github/Wuuuuu05/News/blob/main/News.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests
from bs4 import BeautifulSoup

# 利用 requests 對 API 來源發送一個請求
response = requests.get('https://udn.com/news/breaknews/1')
soup = BeautifulSoup(response.text)

news = []
for link in soup.find_all('h3', class_='rounded-thumb__title')[:4]:
  news_url = link.a['href']
  news_response = requests.get('https://udn.com' + news_url)
  news_soup = BeautifulSoup(news_response.text)
  news_content = news_soup.find('div', class_='article-content__paragraph').text.strip().replace('\n', ' ')
  news.append(news_content)

# 安裝 jieba 中文斷詞套件
# !pip install jieba 

# 下載官方字典檔
# !wget https://raw.githubusercontent.com/fxsjy/jieba/master/extra_dict/dict.txt.big


# 載入套件與字典檔
import jieba
jieba.load_userdict("dict.txt.big")

# 精確模式斷詞
tokens = []
word_count = {}
for d in news:
  token = list(jieba.cut(d, HMM=False)) # token = d 字串斷詞結果
  tokens.append(token)
  # 將斷詞後的結果計算成每個單字的出現次數（詞頻）
  for w in token:
    if w not in word_count:
      word_count[w] = 1
    else:
      word_count[w] += 1
print(word_count)
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: jieba in /usr/local/lib/python3.9/dist-packages (0.42.1)
# --2023-04-12 08:54:57--  https://raw.githubusercontent.com/fxsjy/jieba/master/extra_dict/dict.txt.big
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.110.133, 185.199.111.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 8583143 (8.2M) [text/plain]
# Saving to: ‘dict.txt.big.1’
#
# dict.txt.big.1      100%[===================>]   8.18M  --.-KB/s    in 0.09s
#
# 2023-04-12 08:54:57 (90.3 MB/s) - ‘dict.txt.big.1’ saved [8583143/8583143]
#
# {'淡江大學': 8, '知名': 4, '戰略': 5, '學者': 4, '王': 7, '高成': 6, '教授': 6, '，': 90, '今天': 4, '清晨': 5, '驚': 4, '傳': 6, '在': 17, '校內': 4, '墜樓': 6, '身亡': 3, '。': 24, '圖': 2, '／': 3, '翻': 3, '攝': 3, '淡江': 1, '時報': 1, '前': 2, '國際事務': 4, '副校長': 3, '消防局': 1, '派出': 1, '救護': 2, '人員': 3, '趕': 2, '抵': 2, '時': 4, '檢查': 2, '發現': 2, '已': 3, '無': 1, '呼吸': 1, '心跳': 1, '明顯': 1, '死亡': 3, '校方': 2, '證實': 2, '他': 4, '留有': 1, '遺書': 2, '表示': 4, '因': 3, '腦部': 1, '病變': 1, '智能': 1, '失': 1, '無法': 3, '進行': 1, '教學': 1, '、': 15, '研究': 1, '後續': 2, '由': 2, '警方': 3, '調查': 2, '釐清': 1, '死因': 1, ' ': 124, '\r': 13, '於': 3, '8': 1, '11': 1, '分': 1, '許': 1, '接獲': 1, '119': 1, '轉報': 1, '立刻': 1, '派員': 1, '驚聲': 2, '大樓': 2, '當時': 1, '男子': 2, '確定': 1, '員警': 1, '立即': 1, '用': 1, '帷幕': 1, '覆蓋': 1, '大體': 1, '鑑識': 1, '12': 3, '樓窗': 2, '邊': 4, '等': 2, '位置': 1, '找到': 2, '相關': 2, '遺留物': 2, '和': 2, '並': 4, '通知': 1, '死者': 1, '妻子': 1, '協助': 2, '是': 6, '前任': 1, '學養': 1, '深厚': 1, '對': 2, '學校': 2, '貢獻': 1, '良多': 1, '發生': 1, '此事': 2, '深感': 1, '震驚': 1, '遺憾': 1, '將': 1, '家屬': 1, '妥善': 1, '料理': 1, '後事': 1, '現年': 1, '62': 1, '歲': 2, '台大': 1, '政治系': 2, '政治': 1, '研究所': 2, '畢業': 1, '後': 4, '美國賓夕法尼亞大學': 1, '取得': 1, '博士': 1, '歷任': 1, '與': 2, '所長': 1, '學院院長': 1, '國內': 1, '的': 24, '記者': 4, '林': 2, '昭彰': 2, '★': 1, '珍惜': 1, '生命': 1, '若': 1, '您': 1, '或': 1, '身邊': 1, '人': 2, '有': 10, '心理': 1, '困擾': 1, '可撥打': 1, '安心': 1, '專線': 3, '：': 9, '1925': 1, '｜': 2, '生命線': 1, '協': 1, '談': 1, '1995': 1, '張老師': 1, '1980': 1, '大陸': 4, '網友': 9, '近日': 2, '小': 4, '紅': 2, '書': 2, '發文': 2, '指': 2, '爸爸': 9, '臨終前': 3, '手': 2, '寫出': 1, '兩句': 1, '遺言': 3, '卻': 1, '為': 4, '過分': 2, '潦草': 2, '她': 2, '讀懂': 2, '於是': 1, '向': 2, '求助': 3, '「': 15, '有人': 2, '可以': 3, '認出來': 2