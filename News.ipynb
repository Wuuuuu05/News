# %% [markdown]
# <a href="https://colab.research.google.com/github/Wuuuuu05/News/blob/main/News.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests
from bs4 import BeautifulSoup

# 利用 requests 對 API 來源發送一個請求
response = requests.get('https://udn.com/news/breaknews/1')
soup = BeautifulSoup(response.text)

news = []
for link in soup.find_all('h3', class_='rounded-thumb__title')[:4]:
  news_url = link.a['href']
  news_response = requests.get('https://udn.com' + news_url)
  news_soup = BeautifulSoup(news_response.text)
  news_content = news_soup.find('div', class_='article-content__paragraph').text.strip().replace('\n', ' ')
  news.append(news_content)

# 安裝 jieba 中文斷詞套件
# !pip install jieba 

# 下載官方字典檔
# !wget https://raw.githubusercontent.com/fxsjy/jieba/master/extra_dict/dict.txt.big


# 載入套件與字典檔
import jieba
jieba.load_userdict("dict.txt.big")

# 精確模式斷詞
tokens = []
word_count = {}
for d in news:
  token = list(jieba.cut(d, HMM=False)) # token = d 字串斷詞結果
  tokens.append(token)
  # 將斷詞後的結果計算成每個單字的出現次數（詞頻）
  for w in token:
    if w not in word_count:
      word_count[w] = 1
    else:
      word_count[w] += 1

# 依照出現次數由多到少進行排序
word_count = dict(sorted(word_count.items(), key=lambda item: item[1], reverse = True))
print(word_count)
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: jieba in /usr/local/lib/python3.9/dist-packages (0.42.1)
# --2023-04-12 09:19:07--  https://raw.githubusercontent.com/fxsjy/jieba/master/extra_dict/dict.txt.big
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 8583143 (8.2M) [text/plain]
# Saving to: ‘dict.txt.big.4’
#
# dict.txt.big.4      100%[===================>]   8.18M  --.-KB/s    in 0.09s
#
# 2023-04-12 09:19:07 (90.9 MB/s) - ‘dict.txt.big.4’ saved [8583143/8583143]
#
# {'，': 124, ' ': 114, '。': 28, '的': 24, '女': 22, '「': 21, '」': 21, '學生': 21, '\r': 19, '、': 18, '在': 17, '彭': 17, '為': 13, '2': 13, '：': 11, '我': 11, '和': 10, '網友': 10, '她': 10, '月': 10, '名': 10, '有': 9, '爸爸': 9, '淡江大學': 8, '是': 8, '發生': 8, '懷孕': 8, '王': 7, '傳': 7, '並': 7, '了': 7, '高成': 6, '教授': 6, '墜樓': 6, '後': 6, '人': 6, '個': 6, '也': 6, '交往': 6, '戰略': 5, '清晨': 5, '已': 5, '他': 5, '表示': 5, '於': 5, '歲': 5, '大陸': 5, '臨終': 5, '沒有': 5, '年': 5, '性行': 5, '兩': 5, '健': 5, '保': 5, '卡': 5, '知名': 4, '學者': 4, '今天': 4, '驚': 4, '校內': 4, '／': 4, '國際事務': 4, '邊': 4, '對': 4, '與': 4, '？': 4, '寫': 4, '但': 4, '哭': 4, '給': 4, '到': 4, '\u3000': 4, '1': 4, '內': 4, '男': 4, '家長': 4, '人民幣': 4, '6': 4, '住處': 4, '診所': 4, '同學': 4, '次': 4, '身亡': 3, '翻': 3, '攝': 3, '副校長': 3, '人員': 3, '發現': 3, '校方': 3, '因': 3, '無法': 3, '由': 3, '警方': 3, '調查': 3, '當時': 3, '12': 3, '學校': 3, '或': 3, '專線': 3, '小': 3, '指': 3, '臨終前': 3, '遺言': 3, '向': 3, '求助': 3, '看': 3, '出': 3, '淚': 3, '崩': 3, '媽媽': 3, '說': 3, '拿': 3, '原': 3, '這': 3, '你': 3, '不': 3, '爸': 3, '老師': 3, '《': 3, '》': 3, '消息': 3, '教師': 3, '時間': 3, '48': 3, '發展': 3, '更': 3, '紅包': 3, '金額': 3, '20': 3, '（': 3, '萬元': 3, '）': 3, '都': 3, '墮胎': 3, '國三': 3, '人工流產': 3, '；': 3, '犯': 3, '圖': 2, '前': 2, '救護': 2, '趕': 2, '抵': 2, '時': 2, '檢查': 2, '心跳': 2, '死亡': 2, '證實': 2, '遺書': 2, '8': 2, '11': 2, '立刻': 2, '驚聲': 2, '大樓': 2, '男子': 2, '用': 2, '樓窗': 2, '等': 2, '找到': 2, '相關': 2, '遺留物': 2, '協助': 2, '政治系': 2, '研究所': 2, '記者': 2, '林': 2, '昭彰': 2, '｜': 2, '近日': 2, '紅': 2, '書': 2, '發文': 2, '手': 2, '過分': 2, '潦草': 2, '讀懂': 2, '有人': 2, '可以': 2, '認出來': 2, '嗎': 2, '一致': 2, '解讀': 2, '字': 2, '真的': 2, '該': 2, '由於': 2, '讓': 2, '出來': 2, '一行': 2, 'po': 2, '留下': 2, '─': 